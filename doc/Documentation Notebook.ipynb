# %% [markdown]
# # Installation

# %% [markdown]
# Pip - PyPI

# %%
# !pip install grplot

# %% [markdown]
# Conda

# %%
# !conda install -c conda-forge grplot

# %% [markdown]
# # How to Update

# %% [markdown]
# Pip - PyPI

# %%
# !pip install --upgrade grplot

# %% [markdown]
# Conda

# %%
# !conda update grplot

# %% [markdown]
# # Version

# %%
import grplot


help(grplot)
# Out:
# Help on package grplot:
#
# NAME
#     grplot
#
# PACKAGE CONTENTS
#     analytic (package)
#     features (package)
#     hotfix (package)
#     setting
#     utils (package)
#
# FUNCTIONS
#     plot2d(
#         plot,
#         df,
#         x=None,
#         y=None,
#         Nx=None,
#         Ny=None,
#         figsize=[8, 6],
#         pad=6,
#         hpad=None,
#         wpad=None,
#         filter=None,
#         hue=None,
#         size=None,
#         fontsize=10,
#         tick_fontsize=None,
#         legend_fontsize=None,
#         text_fontsize=None,
#         label_fontsize=None,
#         title_fontsize=None,
#         sep=',',
#         xsep=None,
#         ysep=None,
#         lim=None,
#         xlim=None,
#         ylim=None,
#         log=None,
#         xlog=None,
#         ylog=None,
#         dt=None,
#         xdt=None,
#         ydt=None,
#         tick_add=None,
#         xtick_add=None,
#         ytick_add=None,
#         rot=None,
#         xrot=None,
# ...

# %% [markdown]
# # Basic Understanding

# %% [markdown]
# ## Argument

# %% [markdown]
# <br>Here I tell you how to pass the argument into the plot function<br>
# <i>ordinary argument:</i>
# <br>arg = return
# <br>
# <br>
# <i>axes arguments:</i>
# <br>arg = return
# <br>arg = {'[i,j]':return}
# <br>arg = {return:'[i,j]'}
# <br>arg = {return:['[i,j]']}
# <br>
# <br>
# <i>axes-plot arguments:</i>
# <br>arg = return
# <br>arg = {'plot':return}
# <br>arg = {'[i,j]':{'plot':return}}
# <br>arg = {'[i,j]':{return:'plot'}}
# <br>arg = {'[i,j]':{return:['plot']}}
# <br>arg = {'[i,j]':return}}
# <br>arg = {return:'plot'}
# <br>arg = {return:['plot']}
# <br>
# <br>
# <i>axes-axislabel arguments:</i>
# <br>arg = return
# <br>arg = {'axislabel':return}
# <br>arg = {'[i,j]':{'axislabel':return}}
# <br>arg = {'[i,j]':{return:'axislabel'}}
# <br>arg = {'[i,j]':{return:['axislabel']}}
# <br>arg = {'[i,j]':return}}
# <br>arg = {return:'axislabel'}
# <br>arg = {return:['axislabel']}
# <br>
# <br>
# <i>note:</i>
# <br>- 1 row figure uses '[i]' axes argument, e.g. '[1]'
# <br>- multi rows figure uses '[i,j]' axes argument, e.g. '[1,1]'
# <br>- axes argument starts from 1 (*different from matplotlib which starts from 0)

# %% [markdown]
# ## Image Quality Dots per Inch

# %% [markdown]
# Scratch? Here is the solution. Pass below argument before plotting. Bigger value produces a higher quality of direct look and save as image. Usually 300 is enough.

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# ## Unsupported de Python Locale Solution

# %% [markdown]
# Not all environment support the de Python locale. So, the implementation of matplotlib axis formatter for thousand separator will not always work. The other implementation by directly draw string will always work. Just a little bit tricky to handle this by passing below argument before plotting.

# %%
low = -5 # set this lower than the lowest number order in your dataframe
hi = 18 # set this bigger than the biggest number order in your dataframe
mpl.rcParams['axes.formatter.limits'] = [low, hi]

# %% [markdown]
# ## Localized Seaborn Dependency

# %% [markdown]
# As the major update of seaborn comes, this is the best way to keep the production software working.

# %%
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')

# %% [markdown]
# ## Automatic Analytic Tool

# %% [markdown]
# With great demand comes fresh idea.

# %% [markdown]
# # Plot

# %% [markdown]
# ## Relational Plot Family

# %% [markdown]
# ### Scatter Plot
# Draw a scatter plot with possibility of several semantic groupings.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'scatterplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis text annotation.
# <br>
# <br>
# <b>xtext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis text annotation.
# <br>
# <br>
# <b>ytext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis text annotation.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce points with different colors. Can be either categorical or numeric, although color mapping will behave differently in latter case.
# <br>
# <br>
# <b>size: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce points with different sizes. Can be either categorical or numeric, although size mapping will behave differently in latter case.
# <br>
# <br>
# <b>style: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce points with different markers. Can have a numeric dtype but will always be treated as categorical.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>sizes: list, tuple, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# An object that determines how sizes are chosen when size is used. It can always be a list of size values. When size is numeric, it can also be a tuple specifying the minimum and maximum size to use such that other values are normalized within this range.
# <br>
# <br>
# <b>size_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specified order for appearance of the size variable levels, otherwise they are determined from the data. Not relevant when the size variable is numeric.
# <br>
# <br>
# <b>size_norm: tuple, Normalize object, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for scaling plot objects when the size variable is numeric.
# <br>
# <br>
# <b>markers: bool or list</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# Object determining how to draw the markers for different levels of the style variable. Setting to True will use default markers, or you can pass a list of markers or a dictionary mapping levels of the style variable to markers. Setting to False will draw marker-less lines. Markers are specified as in matplotlib.
# <br>
# <br>
# <b>style_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specified order for appearance of the style variable levels otherwise they are determined from the data. Not relevant when the style variable is numeric.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>legend: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto', 'brief', 'full', or False</i>
# <br>
# How to draw the legend. If 'brief', numeric hue and size variables will be represented with a sample of evenly spaced values. If 'full', every group will get an entry in the legend. If 'auto', choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='scatterplot', 
            df=tips.head(5), 
            x='tip', 
            y='total_bill', 
            sep='.c', 
            tick_add='Rp(_)',
            text=True, 
            title='total_bill vs tip rate')

# %% [markdown]
# ### Line Plot
# Draw a line plot with possibility of several semantic groupings.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'lineplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis text annotation.
# <br>
# <br>
# <b>xtext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis text annotation.
# <br>
# <br>
# <b>ytext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis text annotation.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce lines with different colors. Can be either categorical or numeric, although color mapping will behave differently in latter case.
# <br>
# <br>
# <b>size: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce lines with different widths. Can be either categorical or numeric, although size mapping will behave differently in latter case.
# <br>
# <br>
# <b>style: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable that will produce lines with different dashes and/or markers. Can have a numeric dtype but will always be treated as categorical.
# <br>
# <br>
# <b>units: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Grouping variable identifying sampling units. When used, a separate line will be drawn for each unit with appropriate semantics, but no legend entry will be added. Useful for showing distribution of experimental replicates when exact identities are not needed.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Data values or column used to compute weighted estimation. Note that use of weights currently limits the choice of statistics to a ‘mean’ estimator and ‘ci’ errorbar.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>sizes: list, tuple, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# An object that determines how sizes are chosen when size is used. It can always be a list of size values. When size is numeric, it can also be a tuple specifying the minimum and maximum size to use such that other values are normalized within this range.
# <br>
# <br>
# <b>size_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specified order for appearance of the size variable levels, otherwise they are determined from the data. Not relevant when the size variable is numeric.
# <br>
# <br>
# <b>size_norm: tuple, Normalize object, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for scaling plot objects when the size variable is numeric.
# <br>
# <br>
# <b>dashes: bool or list</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# Object determining how to draw the lines for different levels of the style variable. Setting to True will use default dash codes, or you can pass a list of dash codes. Setting to False will use solid lines for all subsets. Dashes are specified as in matplotlib: a tuple of (segment, gap) lengths, or an empty string to draw a solid line.
# <br>
# <br>
# <b>markers: bool, list, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Object determining how to draw the markers for different levels of the style variable. Setting to True will use default markers or you can pass a list of markers. Setting to False will draw marker-less lines. Markers are specified as in matplotlib.
# <br>
# <br>
# <b>style_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specified order for appearance of the style variable levels otherwise they are determined from the data. Not relevant when the style variable is numeric.
# <br>
# <br>
# <b>estimator: name of pandas method or callable</b>, default: 'mean'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for aggregating across multiple observations of the y variable at the same x level. If None, all observations will be drawn.
# <br>
# <br>
# <b>errorbar: str, tuple, or callable</b>, default: ('ci', 95)
# <br>
# <i>axes-plot arguments</i>
# <br>
# Name of errorbar method (either "ci", "pi", "se", or "sd"), or a tuple with a method name and a level parameter, or a function that maps from a vector to a (min, max) interval, or None to hide errorbar.
# <br>
# <br>
# <b>n_boot: int</b>, default: 1000
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of bootstraps to use for computing the confidence interval.
# <br>
# <br>
# <b>seed: int, numpy.random.Generator, numpy.random.RandomState, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Seed or random number generator for reproducible bootstrapping.
# <br>
# <br>
# <b>orient: str</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'x' or 'y'</i>
# <br>
# Dimension along which the data are sorted / aggregated. Equivalently, the “independent variable” of the resulting function.
# <br>
# <br>
# <b>sort: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, the data will be sorted by the x and y variables, otherwise lines will connect points in the order they appear in the dataset.
# <br>
# <br>
# <b>err_style: str</b>, default: 'band'
# <br>
# <i>axes-plot arguments with the return is 'band' or 'bars'</i>
# <br>
# Whether to draw the confidence intervals with translucent error bands or discrete error bars.
# <br>
# <br>
# <b>err_kws: dict of keyword arguments or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional parameters to control the aesthetics of the error bars. The kwargs are passed either to matplotlib.axes.Axes.fill_between() or matplotlib.axes.Axes.errorbar(), depending on err_style.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>legend: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto', 'brief', 'full', or False</i>
# <br>
# How to draw the legend. If 'brief', numeric hue and size variables will be represented with a sample of evenly spaced values. If 'full', every group will get an entry in the legend. If 'auto', choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


flights = gs.load_dataset('flights')
may_flights = flights.query("month == 'May'")
ax = plot2d(plot='lineplot+scatterplot', 
            df=may_flights, 
            x='year', 
            y='passengers', 
            sep={'passengers':'.', 'year':None},
            text=True, 
            ystatdesc='count+unique',
            title='may passengers vs year')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


flights = gs.load_dataset('flights')
ax = plot2d(plot='lineplot', 
            df=flights, 
            x='year', 
            y='passengers', 
            sep={'passengers':'.', 'year':None},
            text=True, 
            ystatdesc='count+unique',
            title='passengers vs year',
            legend_loc='upper left',
            errorbar=('ci', 95),
            marker='o')

# %% [markdown]
# ## Distribution Plot Family

# %% [markdown]
# ### Hist Plot
# Plot univariate or bivariate histograms to show distributions of datasets.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'histplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# Both x-axis and y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>xtext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# x-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>ytext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# If provided, weight the contribution of the corresponding data points towards the count in each bin by these factors.
# <br>
# <br>
# <b>stat: str</b>, default: 'count'
# <br>
# <i>axes-plot arguments with the return is 'count', 'frequency', 'probability', 'proportion', 'percent', or 'density'</i>
# <br>
# Aggregate statistic to compute in each bin.
# <br>- 'count', to show the number of observations in each bin.
# <br>- 'frequency', to show the number of observations divided by the bin width.
# <br>- 'probability' or 'proportion', to normalize such that bar heights sum to 1.
# <br>- 'percent', to normalize such that bar heights sum to 100.
# <br>- 'density', to normalize such that the total area of the histogram equals 1.
# <br>
# <br>
# <b>bins: str, float, or list</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Generic bin parameter that can be the name of a reference rule, the number of bins, or the breaks of the bins. Passed to numpy.histogram_bin_edges().
# <br>
# <br>
# <b>binwidth: float, pair of float, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of each bin, overrides bins but can be used with binrange.
# <br>
# <br>
# <b>binrange: pair of float, a pair of pairs, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Lowest and highest value for bin edges; can be used either with bins or binwidth. Defaults to data extremes.
# <br>
# <br>
# <b>discrete: bool or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, default to binwidth=1 and draw the bars so that they are centered on their corresponding data points. This avoids 'gaps' that may otherwise appear when using discrete (integer) data.
# <br>
# <br>
# <b>cumulative: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, plot the cumulative counts as bins increase.
# <br>
# <br>
# <b>common_bins: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use the same bins when semantic variables produce multiple plots. If using a reference rule to determine the bins, it will be computed with the full dataset.
# <br>
# <br>
# <b>common_norm: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True and using a normalized statistic, the normalization will apply over the full dataset. Otherwise, normalize each histogram independently.
# <br>
# <br>
# <b>multiple: str</b>, default: 'layer'
# <br>
# <i>axes-plot arguments with the return is 'layer', 'dodge', 'stack', or 'fill'</i>
# <br>
# Approach to resolving multiple elements when semantic mapping creates subsets. Only relevant with univariate data.
# <br>
# <br>
# <b>element: str</b>, default: 'bars'
# <br>
# <i>axes-plot arguments with the return is 'bars', 'step', or 'poly'</i>
# <br>
# Visual representation of the histogram statistic. Only relevant with univariate data.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, fill in the space under the histogram. Only relevant with univariate data.
# <br>
# <br>
# <b>shrink: float</b>, default: 1
# <br>
# <i>axes-plot arguments</i>
# <br>
# Scale the width of each bar relative to the binwidth by this factor. Only relevant with univariate data.
# <br>
# <br>
# <b>kde: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, compute a kernel density estimate to smooth the distribution and show on the plot as (one or more) line(s). Only relevant with univariate data.
# <br>
# <br>
# <b>kde_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Parameters that control the KDE computation, as in kdeplot().
# <br>
# <br>
# <b>line_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Parameters that control the KDE visualization, passed to matplotlib.axes.Axes.plot().
# <br>
# <br>
# <b>thresh: float or None</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Cells with a statistic less than or equal to this value will be transparent. Only relevant with bivariate data.
# <br>
# <br>
# <b>pthresh: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Like thresh, but a value in the range 0 until 1 such that cells with aggregate counts (or other statistics, when used) up to this proportion of the total will be transparent.
# <br>
# <br>
# <b>pmax: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# A value in the range 0 until 1 that sets that saturation point for the colormap at a value such that cells below is constistute this proportion of the total count (or other statistic, when used).
# <br>
# <br>
# <b>cbar: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, add a colorbar to annotate the color mapping in a bivariate plot. Note: Does not currently support plots with a hue variable well.
# <br>
# <br>
# <b>cbar_ax: matplotlib.axes.Axes or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Pre-existing axes for the colorbar.
# <br>
# <br>
# <b>cbar_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional parameters passed to matplotlib.figure.Figure.colorbar().
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Single color specification for when hue mapping is not used. Otherwise, the plot will try to hook into the matplotlib property cycle.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>legend: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If False, suppress the legend for semantic variables.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='histplot', 
            df=tips, 
            x='total_bill', 
            xsep='.c', 
            ysep='.',
            statdesc={'total_bill':'general'}, 
            xtick_add='Rp(_)', 
            ytext='h', 
            title='Histogram Count vs total_bill', 
            kde=True, 
            alpha=0.75)

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='histplot', 
            df=tips, 
            x='total_bill', 
            hue='sex',
            xsep='.c', 
            ysep='.',
            statdesc={'total_bill':'general'}, 
            xtick_add='Rp(_)', 
            ytext='h', 
            title='Histogram Count vs total_bill', 
            multiple='stack',
            kde=True, 
            alpha=0.75)

# %% [markdown]
# ### KDE Plot
# Plot univariate or bivariate distributions using kernel density estimation.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'kdeplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# If provided, weight the kernel density estimation using these values.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Single color specification for when hue mapping is not used. Otherwise, the plot will try to hook into the matplotlib property cycle.
# <br>
# <br>
# <b>fill: bool or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, fill in the area under univariate density curves or between bivariate contours. If None, the default depends on multiple.
# <br>
# <br>
# <b>multiple: str</b>, default: 'layer'
# <br>
# <i>axes-plot arguments with the return is 'layer', 'stack', or 'fill'</i>
# <br>
# Method for drawing multiple elements when semantic mapping creates subsets. Only relevant with univariate data.
# <br>
# <br>
# <b>common_norm: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, scale each conditional density by the number of observations such that the total area under all densities sums to 1. Otherwise, normalize each density independently.
# <br>
# <br>
# <b>common_grid: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use the same evaluation grid for each kernel density estimate. Only relevant with univariate data.
# <br>
# <br>
# <b>cumulative: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, estimate a cumulative distribution function.
# <br>
# <br>
# <b>bw_method: str, scalar, or callable</b>, default: 'scott'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for determining the smoothing bandwidth to use; passed to scipy.stats.gaussian_kde.
# <br>
# <br>
# <b>bw_adjust: float</b>, default: 1
# <br>
# <i>axes-plot arguments</i>
# <br>
# Factor that multiplicatively scales the value chosen using bw_method. Increasing will make the curve smoother.
# <br>
# <br>
# <b>warn_singular: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, issue a warning when trying to estimate the density of data with zero variance.
# <br>
# <br>
# <b>levels: int or list</b>, default: 10
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of contour levels or values to draw contours at. A vector argument must have increasing values in the range 0 until 1. Levels correspond to iso-proportions of the density: e.g., 20% of the probability mass will lie below the contour drawn for 0.2. Only relevant with bivariate data.
# <br>
# <br>
# <b>thresh: float</b>, default: 0.05
# <br>
# <i>axes-plot arguments with the return is a float in the range 0 until 1</i>
# <br>
# Lowest iso-proportion level at which to draw a contour line. Ignored when levels is a vector. Only relevant with bivariate data.
# <br>
# <br>
# <b>gridsize: int</b>, default: 200
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of points on each dimension of the evaluation grid.
# <br>
# <br>
# <b>cut: float</b>, default: 3
# <br>
# <i>axes-plot arguments</i>
# <br>
# Factor, multiplied by the smoothing bandwidth, that determines how far the evaluation grid extends past the extreme datapoints. When set to 0, truncate the curve at the data limits.
# <br>
# <br>
# <b>clip: pair of float, a pair of such pairs, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Do not evaluate the density outside of these limits.
# <br>
# <br>
# <b>legend: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If False, suppress the legend for semantic variables.
# <br>
# <br>
# <b>cbar: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, add a colorbar to annotate the color mapping in a bivariate plot. Note: Does not currently support plots with a hue variable well.
# <br>
# <br>
# <b>cbar_ax: matplotlib.axes.Axes or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Pre-existing axes for the colorbar.
# <br>
# <br>
# <b>cbar_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional parameters passed to matplotlib.figure.Figure.colorbar().
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='kdeplot', 
            df=tips, 
            x='total_bill', 
            xsep='.c', 
            ysep='.',
            statdesc={'total_bill':'general'}, 
            xtick_add='Rp(_)', 
            title='KDE Density vs total_bill')

# %% [markdown]
# ### ECDF Plot
# Plot empirical cumulative distribution functions.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'ecdfplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis text annotation.
# <br>
# <br>
# <b>xtext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis text annotation.
# <br>
# <br>
# <b>ytext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis text annotation.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# If provided, weight the contribution of the corresponding data points towards the cumulative distribution using these values.
# <br>
# <br>
# <b>stat: str</b>, default: 'proportion'
# <br>
# <i>axes-plot arguments with the return is 'proportion', 'percent', or 'count'</i>
# <br>
# Distribution statistic to compute.
# <br>
# <br>
# <b>complementary: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use the complementary CDF (1 - CDF).
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>legend: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If False, suppress the legend for semantic variables.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='ecdfplot', 
            df=tips.head(5), 
            x='tip', 
            xsep='.c', 
            ysep='.', 
            xtick_add='Rp(_)',
            text=True, 
            title='ECDF Proportion vs tip')

# %% [markdown]
# ### Rug Plot
# Plot marginal distributions by drawing ticks along the x and y axes.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'rugplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>height: float</b>, default: 0.025
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of axes extent covered by each rug element.
# <br>
# <br>
# <b>expand_margins: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, increase the axes margins by the height of the rug to avoid overlap with other elements.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Either a pair of values that set the normalization range in data units or an object that will map from data units into a 0 until 1 interval. Usage implies numeric mapping.
# <br>
# <br>
# <b>legend: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If False, do not add a legend for semantic variables.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='kdeplot+rugplot', 
            df=tips, 
            x='total_bill', 
            xsep='.c', 
            ysep='.',
            statdesc={'total_bill':'general'}, 
            xtick_add='Rp(_)', 
            title='KDE-Rug Density vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='scatterplot+rugplot', 
            df=tips, 
            x='total_bill', 
            y='tip',
            sep='.c',
            tick_add='Rp(_)', 
            title='KDE-Rug tip vs total_bill')

# %% [markdown]
# ### Pie Plot
# Plot pie chart to show distributions of datasets.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'pieplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis text annotation.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Text annotation.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>explode: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# If not None, is a len(x) array which specifies the fraction of the radius with which to offset each wedge.
# <br>
# <br>
# <b>colors: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# A sequence of colors through which the pie chart will cycle. If None, will use the colors in the currently active cycle.
# <br>
# <br>
# <b>hatch: str, list, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Hatching pattern applied to all pie wedges or sequence of patterns through which the chart will cycle.
# <br>
# <br>
# <b>autopct: str, callable, or None</b>, default: sep
# <br>
# <i>axes-plot arguments</i>
# <br>
# If not None, is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be fmt % pct. If it is a function, it will be called.
# <br>
# <br>
# <b>pctdistance: float</b>, default: 0.6
# <br>
# <i>axes-plot arguments</i>
# <br>
# The ratio between the center of each pie slice and the start of the text generated by autopct. Ignored if autopct is None.
# <br>
# <br>
# <b>shadow: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Draw a shadow beneath the pie.
# <br>
# <br>
# <b>normalize: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, always make a full pie by normalizing x so that sum(x) == 1. False makes a partial pie if sum(x) <= 1 and raises a ValueError for sum(x) > 1.
# <br>
# <br>
# <b>labeldistance: float or None</b>, default: 1.1
# <br>
# <i>axes-plot arguments</i>
# <br>
# The radial distance at which the pie labels are drawn. If set to None, label are not drawn, but are stored for use in legend().
# <br>
# <br>
# <b>startangle: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# The angle by which the start of the pie is rotated, counterclockwise from the x-axis.
# <br>
# <br>
# <b>radius: float</b>, default: 1
# <br>
# <i>axes-plot arguments</i>
# <br>
# The radius of the pie.
# <br>
# <br>
# <b>counterclock: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify fractions direction, clockwise or counterclockwise.
# <br>
# <br>
# <b>wedgeprops: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Dict of arguments passed to the wedge objects making the pie. For example, you can pass in wedgeprops = {'linewidth': 3} to set the width of the wedge border lines equal to 3. For more details, look at the doc/arguments of matplotlib wedge object. By default clip_on=False.
# <br>
# <br>
# <b>textprops: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Dict of arguments to pass to the text objects.
# <br>
# <br>
# <b>center: [float, float]</b>, default: [0, 0]
# <br>
# <i>axes-plot arguments</i>
# <br>
# The coordinates of the center of the chart.
# <br>
# <br>
# <b>frame: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Plot Axes frame with the chart if true.
# <br>
# <br>
# <b>rotatelabels: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Plot Axes frame with the chart if true.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='pieplot', 
            df=tips, 
            x='day', 
            sep='.',
            text=True, 
            title='Pie of day')

# %% [markdown]
# ### Treemaps Plot
# Plot treemaps chart to show distributions of datasets.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'treemapsplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis text annotation.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Text annotation.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>norm_x: float</b>, default: 100
# <br>
# <i>axes-plot arguments</i>
# <br>
# x value for normalization.
# <br>
# <br>
# <b>norm_y: float</b>, default: 100
# <br>
# <i>axes-plot arguments</i>
# <br>
# y value for normalization.
# <br>
# <br>
# <b>color: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# A sequence of colors through which the treemaps chart will cycle. If None, will use the colors in the currently active cycle.
# <br>
# <br>
# <b>treemaps_pad: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Draw rectangles with a small gap between them.
# <br>
# <br>
# <b>bar_kwargs: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Keyword arguments passed to matplotlib.Axes.bar.
# <br>
# <br>
# <b>text_kwargs: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Keyword arguments passed to matplotlib.Axes.text.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='treemapsplot', 
            df=tips, 
            x='day', 
            sep='.',
            text=True, 
            title='Treemaps of day')

# %% [markdown]
# ### Packed Bubbles Plot
# Plot packed bubbles chart to show distributions of datasets.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'packedbubblesplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis text annotation.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Text annotation.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>bubble_spacing: float</b>, default: 0.1
# <br>
# <i>axes-plot arguments</i>
# <br>
# Space between bubbles.
# <br>
# <br>
# <b>color: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# A sequence of colors through which the packed bubbles chart will cycle. If None, will use the colors in the currently active cycle.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='packedbubblesplot', 
            df=tips, 
            x='day', 
            figsize=[6,6],
            sep='.',
            text=True, 
            title='Packed Bubbles of day')

# %% [markdown]
# ## Categorical Plot Family

# %% [markdown]
# ### Strip Plot
# Draw a scatterplot where one variable is categorical.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'stripplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>jitter: float or bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# Amount of jitter (only along the categorical axis) to apply. This can be useful when you have many points and they overlap, so that it is easier to see the distribution. You can specify the amount of jitter (half the width of the uniform random variable support), or just use True for a good default.
# <br>
# <br>
# <b>dodge: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When using hue nesting, setting this to True will separate the strips for different hue levels along the categorical axis. Otherwise, the points for each level will be plotted on top of each other.
# <br>
# <br>
# <b>orient: str</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', or 'y'</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>size: float or None</b>, default: 5
# <br>
# <i>axes-plot arguments</i>
# <br>
# Radius of the markers, in points.
# <br>
# <br>
# <b>edgecolor: matplotlib.colors</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color of the lines around each point. If you pass 'gray', the brightness is determined by the color palette used for the body of the points.
# <br>
# <br>
# <b>linewidth: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='stripplot', 
            df=tips,
            x='total_bill',
            y='day',
            figsize=[16,6],
            sep='.c',
            xstatdesc='boxplot',
            xtick_add='Rp(_)', 
            title='Strip day vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='boxplot+stripplot', 
            df=tips, 
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='boxplot',     
            xtick_add='Rp(_)', 
            title='Box-Strip day vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='violinplot+stripplot', 
            df=tips, 
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='boxplot',     
            xtick_add='Rp(_)', 
            title='Violin-Strip day vs total_bill')

# %% [markdown]
# ### Swarm Plot
# Draw a categorical scatterplot with non-overlapping points.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'swarmplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>dodge: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When using hue nesting, setting this to True will separate the strips for different hue levels along the categorical axis. Otherwise, the points for each level will be plotted in one swarm.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h',, 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>size: float or None</b>, default: 5
# <br>
# <i>axes-plot arguments</i>
# <br>
# Radius of the markers, in points.
# <br>
# <br>
# <b>edgecolor: matplotlib.colors</b>, default: 'gray'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color of the lines around each point. If you pass 'gray', the brightness is determined by the color palette used for the body of the points.
# <br>
# <br>
# <b>linewidth: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='swarmplot', 
            df=tips,
            x='total_bill',
            y='day',
            figsize=[16,6],
            sep='.c',
            xstatdesc='boxplot',
            xtick_add='Rp(_)', 
            title='Swarm day vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='boxplot+swarmplot', 
            df=tips,
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='general',
            xtick_add='Rp(_)', 
            title='Box-Swarm day vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='violinplot+swarmplot', 
            df=tips,
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='general',
            xtick_add='Rp(_)', 
            title='Violin-Swarm day vs total_bill')

# %% [markdown]
# ### Box Plot
# Draw a box plot to show distributions with respect to categories.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'boxplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use a solid patch. Otherwise, draw as line art.
# <br>
# <br>
# <b>dodge: 'auto', or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>gap: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Shrink on the orient axis by this factor to add a gap between dodged elements.
# <br>
# <br>
# <b>whis: float</b>, default: 1.5
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the IQR past the low and high quartiles to extend the plot whiskers. Points outside this range will be identified as outliers.
# <br>
# <br>
# <b>linecolor: str or matplotlib.colors</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto', 'none', or matplotlib.colors</i>
# <br>
# Proportion of the IQR past the low and high quartiles to extend the plot whiskers. Points outside this range will be identified as outliers.
# <br>
# <br>
# <b>linewidth: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>fliersize: float</b>, default: 5
# <br>
# <i>axes-plot arguments</i>
# <br>
# Size of the markers used to indicate outlier observations.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>showmeans: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Show the arithmetic means.
# <br>
# <br>
# <b>meanprops: dict</b>, default: {'marker':'s', 'markerfacecolor':'white', 'markeredgecolor':'.3'}
# <br>
# <i>ordinary argument</i>
# <br>
# The style of the mean.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='boxplot', 
            df=tips, 
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='boxplot',
            xtick_add='Rp(_)',
            title='Box day vs total_bill')

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='histplot+boxplot', 
            df=tips, 
            x='total_bill', 
            y='sex', 
            figsize=[16,6],
            sep='.c', 
            tick_add={'total_bill':'Rp(_)'},
            hue={'histplot':'sex'},
            xstatdesc='boxplot',
            legend_loc='lower right',
            title='sex vs total_bill',
            alpha={'histplot':0.75})

# %% [markdown]
# ### Violin Plot
# Draw a combination of boxplot and kernel density estimate.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'violinplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use a solid patch. Otherwise, draw as line art.
# <br>
# <br>
# <b>inner: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'box', 'quartile', 'point', 'stick', or None</i>
# <br>
# Representation of the data in the violin interior. One of the following:
# <br>- "box": draw a miniature box-and-whisker plot
# <br>- "quart": show the quartiles of the data
# <br>- "point" or "stick": show each observation
# <br>
# <br>
# <b>split: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Show an un-mirrored distribution, alternating sides when using hue.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>dodge: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto' or bool</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>gap: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Shrink on the orient axis by this factor to add a gap between dodged elements.
# <br>
# <br>
# <b>linewidth: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>linecolor: str or None</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto', 'none' or color</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>cut: float</b>, default: 2
# <br>
# <i>axes-plot arguments</i>
# <br>
# Distance, in units of bandwidth size, to extend the density past the extreme datapoints. Set to 0 to limit the violin range within the range of the observed data (i.e., to have the same effect as trim=True in ggplot).
# <br>
# <br>
# <b>gridsize: int</b>, default: 100
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of points in the discrete grid used to compute the kernel density estimate.
# <br>
# <br>
# <b>bw_method: str or float</b>, default: 'scott'
# <br>
# <i>axes-plot arguments with the return is 'scott', 'silverman', or float</i>
# <br>
# Either the name of a reference rule or the scale factor to use when computing the kernel bandwidth. The actual kernel size will be determined by multiplying the scale factor by the standard deviation of the data within each bin.
# <br>
# <br>
# <b>bw_adjust: float</b>, default: 1
# <br>
# <i>axes-plot arguments with the return is 'scott', 'silverman', or float</i>
# <br>
# Factor that scales the bandwidth to use more or less smoothing.
# <br>
# <br>
# <b>density_norm: str</b>, default: 'area'
# <br>
# <i>axes-plot arguments with the return is 'area', 'count', or 'width'</i>
# <br>
# Method that normalizes each density to determine the violin’s width. If area, each violin will have the same area. If count, the width will be proportional to the number of observations. If width, each violin will have the same width.
# <br>
# <br>
# <b>common_norm: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, normalize the density across all violins.
# <br>
# <br>
# <b>hue_norm: tuple or matplotlib.colors.Normalize</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='violinplot', 
            df=tips, 
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='boxplot',
            xtick_add='Rp(_)',
            title='Violin day vs total_bill',
            inner='box')

# %% [markdown]
# ### Boxen Plot
# Draw an enhanced box plot for larger datasets.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'boxenplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use a solid patch. Otherwise, draw as line art.
# <br>
# <br>
# <b>dodge: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto' or bool</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>gap: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Shrink on the orient axis by this factor to add a gap between dodged elements.
# <br>
# <br>
# <b>linewidth: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the gray lines that frame the plot elements.
# <br>
# <br>
# <b>linecolor: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color to use for line elements, when fill is True.
# <br>
# <br>
# <b>width_method: str</b>, default: 'exponential'
# <br>
# <i>axes-plot arguments with the return is 'exponential', 'linear', or 'area'</i>
# <br>
# Method to use for the width of the letter value boxes:
# <br>- "exponential": Represent the corresponding percentile
# <br>- "linear": Decrease by a constant amount for each box
# <br>- "area": Represent the density of data points in that box
# <br>
# <br>
# <b>k_depth: str or int</b>, default: 'tukey'
# <br>
# <i>axes-plot arguments with the return is 'tukey', 'proportion', 'trustworthy', 'full', or int</i>
# <br>
# The number of levels to compute and draw in each tail:
# <br>- "tukey": Use log2(n) - 3 levels, covering similar range as boxplot whiskers
# <br>- "proportion": Leave approximately outlier_prop fliers
# <br>- "trusthworthy": Extend to level with confidence of at least trust_alpha
# <br>- "full": Use log2(n) + 1 levels and extend to most extreme points
# <br>
# <br>
# <b>outlier_prop: float</b>, default: 0.007
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of data expected to be outliers; used when k_depth="proportion".
# <br>
# <br>
# <b>trust_alpha: float</b>, default: 0.05
# <br>
# <i>axes-plot arguments</i>
# <br>
# Confidence threshold for most extreme level; used when k_depth="trustworthy".
# <br>
# <br>
# <b>showfliers: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If False, suppress the plotting of outliers.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>box_kws: dict or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Keyword arguments for the box artists; passed to matplotlib.patches.Rectangle.
# <br>
# <br>
# <b>line_kws: dict or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Keyword arguments for the line denoting the median; passed to matplotlib.axes.Axes.plot().
# <br>
# <br>
# <b>flier_kws: dict or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Keyword arguments for the scatter denoting the outlier observations; passed to matplotlib.axes.Axes.scatter().
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='boxenplot', 
            df=tips, 
            x='total_bill',
            y='day',
            figsize=[10,6],
            sep='.c',
            xstatdesc='boxplot',
            xtick_add='Rp(_)',
            title='Boxen day vs total_bill')

# %% [markdown]
# ### Point Plot
# Show point estimates and confidence intervals using scatter plot glyphs.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'pointplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>estimator: str, name of pandas method, callable, or None</b>, default: 'mean'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Statistical function to estimate within each categorical bin.
# <br>
# <br>
# <b>errorbar: str, tuple, callable, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Name of errorbar method (either "ci", "pi", "se", or "sd"), or a tuple with a method name and a level parameter, or a function that maps from a vector to a (min, max) interval, or None to hide errorbar. See the errorbar tutorial for more information.
# <br>
# <br>
# <b>n_boot: int</b>, default: 1000
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of bootstrap iterations to use when computing confidence intervals.
# <br>
# <br>
# <b>seed: int, numpy.random.Generator, numpy.random.RandomState, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Seed or random number generator for reproducible bootstrapping.
# <br>
# <br>
# <b>units: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Identifier of sampling units, which will be used to perform a multilevel bootstrap and account for repeated measures design.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Data values or column used to compute weighted statistics. Note that the use of weights may limit other statistical options.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>markers: str or list</b>, default: 'o'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Markers to use for each of the hue levels.
# <br>
# <br>
# <b>linestyles: str or list</b>, default: '-'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Line styles to use for each of the hue levels.
# <br>
# <br>
# <b>dodge: bool or float</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Amount to separate the points for each level of the hue variable along the categorical axis.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>capsize: float</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the “caps” on error bars.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='pointplot', 
            df=tips, 
            x='time',
            y='total_bill',
            sep='.c',
            ytick_add='Rp(_)',
            title='Point total_bill vs time',
            hue='smoker',
            errorbar=('ci', 95),
            )

# %%
from grplot import plot2d
import grplot_seaborn as gs
import pandas as pd
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


iris = gs.load_dataset('iris')
iris = pd.melt(iris, 'species', var_name='measurement')
ax = plot2d(plot='stripplot+pointplot',
            df=iris,
            x='value', 
            y='measurement',
            sep='.',
            title='measurement vs value',
            hue='species')

# %% [markdown]
# ### Bar Plot
# Show point estimates and confidence intervals as rectangular bars.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'barplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# Both x-axis and y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>xtext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# x-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>ytext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>estimator: str, name of pandas method, callable, or None</b>, default: 'mean'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Statistical function to estimate within each categorical bin.
# <br>
# <br>
# <b>errorbar: str, tuple, callable, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Name of errorbar method (either "ci", "pi", "se", or "sd"), or a tuple with a method name and a level parameter, or a function that maps from a vector to a (min, max) interval, or None to hide errorbar.
# <br>
# <br>
# <b>n_boot: int</b>, default: 1000
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of bootstrap iterations to use when computing confidence intervals.
# <br>
# <br>
# <b>seed: int, numpy.random.Generator, numpy.random.RandomState, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Seed or random number generator for reproducible bootstrapping.
# <br>
# <br>
# <b>units: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Identifier of sampling units, which will be used to perform a multilevel bootstrap and account for repeated measures design.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Data values or column used to compute weighted statistics. Note that the use of weights may limit other statistical options.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use a solid patch. Otherwise, draw as line art.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>dodge: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto' or bool</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>gap: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Shrink on the orient axis by this factor to add a gap between dodged elements.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>capsize: float</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the "caps" on error bars.
# <br>
# <br>
# <b>err_kws: dict or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Parameters of matplotlib.lines.Line2D, for the error bar artists.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='barplot', 
            df=tips, 
            x='day',
            y='total_bill',
            sep='.c',
            ytick_add='Rp(_)',
            ytext='h',
            title='Bar total_bill vs day',
            errorbar=('ci', 95))

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='barplot', 
            df=tips, 
            y='day',
            x='total_bill',
            sep='.c',
            xtick_add='Rp(_)',
            xtext='v',
            title='Bar day vs total_bill',
            hue='sex',
            errorbar=('ci', 95))

# %% [markdown]
# ### Count Plot
# Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'countplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# Both x-axis and y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>xtext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# x-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>ytext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order to plot the categorical levels in, otherwise the levels are inferred from the data objects.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>stat: str</b>, default: 'count'
# <br>
# <i>axes-plot arguments with the return is 'count', 'percent', 'proportion', or 'probability'</i>
# <br>
# Statistic to compute; when not 'count', bar heights will be normalized so that they sum to 100 (for 'percent') or 1 (otherwise) across the plot.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>dodge: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto' or bool</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='histplot', 
            df=tips, 
            x='day',
            sep='.',
            ytext='h',
            title='Count vs day',
            xstatdesc='count+unique')

# %% [markdown]
# ### Pareto Plot
# Draw a combination of barplot and lineplot cumulative percentage.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'paretoplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>text_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for text.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# Both x-axis and y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>xtext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# x-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>ytext: str or None</b>, default: text
# <br>
# <i>axes-axislabel arguments with the base position is 'h', 'v', or 'i' can be passed by 'position' or 'position1+position2'</i>
# <br>
# y-axis text annotation. 'h' stands for horizontal. 'v' stands for vertical. 'i' stands for inside. If ci is not None, text will automatically be put inside the bar.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>hue: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Semantic variable that is mapped to determine the color of plot elements.
# <br>
# <br>
# <b>hue_order: list or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Specify the order of processing and plotting for categorical levels of the hue semantic.
# <br>
# <br>
# <b>estimator: str, name of pandas method, callable, or None</b>, default: 'mean'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Statistical function to estimate within each categorical bin.
# <br>
# <br>
# <b>errorbar: str, tuple, callable, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Name of errorbar method (either "ci", "pi", "se", or "sd"), or a tuple with a method name and a level parameter, or a function that maps from a vector to a (min, max) interval, or None to hide errorbar.
# <br>
# <br>
# <b>n_boot: int</b>, default: 1000
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of bootstrap iterations to use when computing confidence intervals.
# <br>
# <br>
# <b>seed: int, numpy.random.Generator, numpy.random.RandomState, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Seed or random number generator for reproducible bootstrapping.
# <br>
# <br>
# <b>units: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Identifier of sampling units, which will be used to perform a multilevel bootstrap and account for repeated measures design.
# <br>
# <br>
# <b>weights: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# Data values or column used to compute weighted statistics. Note that the use of weights may limit other statistical options.
# <br>
# <br>
# <b>orient: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'v', 'h', 'x', 'y', or None</i>
# <br>
# Orientation of the plot (vertical or horizontal). This is usually inferred based on the type of the input variables, but it can be used to resolve ambiguity when both x and y are numeric or when plotting wide-form data.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>palette: str, list, matplotlib.colors.Colormap, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Method for choosing the colors to use when mapping the hue semantic. String values are passed to color_palette(). List values imply categorical mapping, while a colormap object implies numeric mapping.
# <br>
# <br>
# <b>saturation: float</b>, default: 0.75
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportion of the original saturation to draw colors at. Large patches often look better with slightly desaturated colors, but set this to 1 if you want the plot colors to perfectly match the input color spec.
# <br>
# <br>
# <b>fill: bool</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use a solid patch. Otherwise, draw as line art.
# <br>
# <br>
# <b>hue_norm: tuple, matplotlib.colors.Normalize, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Normalization in data units for colormap applied to the hue variable when it is numeric. Not relevant if hue is categorical.
# <br>
# <br>
# <b>width: float</b>, default: 0.8
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width allotted to each element on the orient axis. When native_scale=True, it is relative to the minimum distance between two values in the native scale.
# <br>
# <br>
# <b>dodge: str or bool</b>, default: 'auto'
# <br>
# <i>axes-plot arguments with the return is 'auto' or bool</i>
# <br>
# When hue mapping is used, whether elements should be narrowed and shifted along the orient axis to eliminate overlap. If "auto", set to True when the orient variable is crossed with the categorical variable or False otherwise.
# <br>
# <br>
# <b>gap: float</b>, default: 0
# <br>
# <i>axes-plot arguments</i>
# <br>
# Shrink on the orient axis by this factor to add a gap between dodged elements.
# <br>
# <br>
# <b>native_scale: bool</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# When True, numeric or datetime values on the categorical axis will maintain their original scaling rather than being converted to fixed indices.
# <br>
# <br>
# <b>formatter: callable or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Function for converting categorical data into strings. Affects both grouping and tick labels.
# <br>
# <br>
# <b>legend: 'auto', 'brief', 'full', or False</b>, default: 'auto'
# <br>
# <i>axes-plot arguments</i>
# <br>
# How to draw the legend. If "brief", numeric hue and size variables will be represented with a sample of evenly spaced values. If "full", every group will get an entry in the legend. If "auto", choose between brief or full representation based on number of levels. If False, no legend data is added and no legend is drawn.
# <br>
# <br>
# <b>capsize: float</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Width of the "caps" on error bars.
# <br>
# <br>
# <b>err_kws: dict or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Parameters of matplotlib.lines.Line2D, for the error bar artists.
# <br>
# <br>
# <b>color2: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Line plot color for all of the elements, or seed for a gradient palette.
# <br>
# <br>
# <b>marker: str or matplotlib.markers</b>, default: '.26'
# <br>
# <i>axes-plot arguments</i>
# <br>
# The marker style. marker can be either an instance of the class or the text shorthand for a particular marker.
# <br>
# <br>
# <b>markersize: float</b>, default: .7
# <br>
# <i>axes-plot arguments</i>
# <br>
# Marker size for line plot.
# <br>
# <br>
# <b>alpha: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the points.
# <br>
# <br>
# <b>alpha2: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Proportional opacity of the line.
# <br>
# <br>
# <b>zorder: int or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Axes order. The default drawing order for axes is patches, lines, text for each plot order.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='paretoplot', 
            df=tips, 
            x='day',
            y='total_bill',
            sep='.c',
            ytick_add='Rp(_)',
            ytext='h+i',
            alpha=0.75,
            alpha2=0.75,
            title='Pareto total_bill vs day')

# %% [markdown]
# ## Regression Plot Family

# %% [markdown]
# ### Reg Plot
# Plot data and a linear regression model fit.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'regplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>x_estimator: name of pandas method, callable, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Apply this function to each unique value of x and plot the resulting estimate. This is useful when x is a discrete variable. If x_ci is given, this estimate will be bootstrapped and a confidence interval will be drawn.
# <br>
# <br>
# <b>x_bins: int, list, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Bin the x variable into discrete bins and then estimate the central tendency and a confidence interval. This binning only influences how the scatterplot is drawn; the regression is still fit to the original data. This parameter is interpreted either as the number of evenly-sized (not necessary spaced) bins or the positions of the bin centers. When this parameter is used, it implies that the default of x_estimator is numpy.mean.
# <br>
# <br>
# <b>x_ci: str, int, or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is 'ci', 'sd', int in the range 0 until 100, or None</i>
# <br>
# Size of the confidence interval used when plotting a central tendency for discrete values of x. If 'ci', defer to the value of the ci parameter. If 'sd', skip bootstrapping and show the standard deviation of the observations in each bin.
# <br>
# <br>
# <b>scatter: bool</b>, default: True
# <br>
# <i>axes-plot arguments with the return is 'ci', 'sd', int in the range 0 until 100, or None</i>
# <br>
# If True, draw a scatterplot with the underlying observations (or the x_estimator values).
# <br>
# <br>
# <b>fit_reg: bool</b>, default: True
# <br>
# <i>axes-plot arguments with the return is 'ci', 'sd', int in the range 0 until 100, or None</i>
# <br>
# If True, estimate and plot a regression model relating the x and y variables.
# <br>
# <br>
# <b>ci: int or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is int in the range 0 until 100</i>
# <br>
# Size of the confidence interval for the regression estimate. This will be drawn using translucent bands around the regression line. The confidence interval is estimated using a bootstrap; for large datasets, it may be advisable to avoid that computation by setting this parameter to None.
# <br>
# <br>
# <b>n_boot: int</b>, default: 1000
# <br>
# <i>axes-plot arguments</i>
# <br>
# Number of bootstrap resamples used to estimate the ci. The default value attempts to balance time and stability; you may want to increase this value for 'final' versions of plots.
# <br>
# <br>
# <b>units: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key in df</i>
# <br>
# If the x and y observations are nested within sampling units, those can be specified here. This will be taken into account when computing the confidence intervals by performing a multilevel bootstrap that resamples both units and observations (within unit). This does not otherwise influence how the regression is estimated or drawn.
# <br>
# <br>
# <b>seed: int, numpy.random.Generator, numpy.random.RandomState, or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Seed or random number generator for reproducible bootstrapping.
# <br>
# <br>
# <b>order: int or None</b>, default: 1
# <br>
# <i>axes-plot arguments</i>
# <br>
# If order is greater than 1, use numpy.polyfit to estimate a polynomial regression.
# <br>
# <br>
# <b>logistic: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, assume that y is a binary variable and use statsmodels to estimate a logistic regression model. Note that this is substantially more computationally intensive than linear regression, so you may wish to decrease the number of bootstrap resamples (n_boot) or set ci to None.
# <br>
# <br>
# <b>lowess: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use statsmodels to estimate a nonparametric lowess model (locally weighted linear regression). Note that confidence intervals cannot currently be drawn for this kind of model.
# <br>
# <br>
# <b>robust: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, use statsmodels to estimate a robust regression. This will de-weight outliers. Note that this is substantially more computationally intensive than standard linear regression, so you may wish to decrease the number of bootstrap resamples (n_boot) or set ci to None.
# <br>
# <br>
# <b>regplot_logx: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, estimate a linear regression of the form y ~ log(x), but plot the scatterplot and regression model in the input space. Note that x must be positive for this to work.
# <br>
# <br>
# <b>x_partial: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key or list-keys in df</i>
# <br>
# Confounding variables to regress out of the x variable before plotting.
# <br>
# <br>
# <b>y_partial: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key or list-keys in df</i>
# <br>
# Confounding variables to regress out of the y variable before plotting.
# <br>
# <br>
# <b>truncate: bool or None</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, the regression line is bounded by the data limits. If False, it extends to the x axis limits.
# <br>
# <br>
# <b>x_jitter: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Add uniform random noise of this size to the x variable. The noise is added to a copy of the data after fitting the regression, and only influences the look of the scatterplot. This can be helpful when plotting variables that take discrete values.
# <br>
# <br>
# <b>y_jitter: float or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Add uniform random noise of this size to the y variable. The noise is added to a copy of the data after fitting the regression, and only influences the look of the scatterplot. This can be helpful when plotting variables that take discrete values.
# <br>
# <br>
# <b>label: str or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Label to apply to either the scatterplot or regression line (if scatter is False) for use in a legend.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color to apply to all plot elements; will be superseded by colors passed in scatter_kws or line_kws.
# <br>
# <br>
# <b>marker: matplotlib.markers or None</b>, default: 'o'
# <br>
# <i>axes-plot arguments</i>
# <br>
# Marker to use for the scatterplot glyphs.
# <br>
# <br>
# <b>scatter_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional keyword arguments to pass to plt.scatter.
# <br>
# <br>
# <b>line_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional keyword arguments to pass to plt.plot.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='regplot', 
            df=tips, 
            x='tip', 
            y='total_bill', 
            sep='.c', 
            tick_add='Rp(_)',
            title='total_bill vs tip rate',
            ci=95)

# %%
from grplot import plot2d
import grplot_seaborn as gs
import numpy as np
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='regplot', 
            df=tips, 
            x='size', 
            y='total_bill', 
            sep='.c', 
            tick_add='Rp(_)',
            title='total_bill vs tip rate',
            ci=95,
            x_ci='ci',
            x_estimator=np.mean)

# %% [markdown]
# ### Resid Plot
# Plot the residuals of a linear regression.

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>plot: 'residplot'</b>
# <br>
# <i>axes arguments with the return can be passed by 'plot' or 'plot1+plot2+...'</i>
# <br>
# Plot type.
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>x: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the x axes.
# <br>
# <br>
# <b>y: str, list, numpy.ndarray, pandas.core.indexes.base.Index, or None</b>, default: None
# <br>
# <i>ordinary argument with the return is key or list-keys in df</i>
# <br>
# Variables that specify positions on the y axes.
# <br>
# <br>
# <b>Nx: int</b>, default: Nx = max(max_Nx, max_Ny) if max(max_Nx, max_Ny) <= 2 else 2
# <br>
# <i>ordinary argument</i>
# <br>
# Figure columns.
# <br>
# <br>
# <b>Ny: int</b>, default: Ny = 1 if max(max_Nx, max_Ny) <= 2 else ceil(max(max_Nx, max_Ny)/2)
# <br>
# <i>ordinary argument</i>
# <br>
# Figure rows.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>pad: float</b>, default: 6
# <br>
# <i>ordinary argument</i>
# <br>
# Padding between the figure edge and the edges of subplots, as a fraction of the font size.
# <br>
# <br>
# <b>hpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding height between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>wpad: float</b>, default: pad
# <br>
# <i>ordinary argument</i>
# <br>
# Padding width between edges of adjacent subplots, as a fraction of the font size.
# <br>
# <br>
# <b>filter: str, pandas.core.series.Series, or None</b>
# <br>
# <i>axes arguments with the return is pandas query or pandas square brackets</i>
# <br>
# Filter dataframe before plotting. Only work for pandas dataframe.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Plot title if subplot is one else subplot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>axes arguments</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>axes arguments</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>legend_loc: str or None</b>, default: 'best'
# <br>
# <i>axes arguments with the return is 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', or 'center'</i>
# <br>
# The location of the legend.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Both x-axis and y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>xsep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# x-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>ysep: str or None</b>, default: sep
# <br>
# <i>axes-axislabel arguments with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# y-axis numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>lim: [float, float] or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis and y-axis limit.
# <br>
# <br>
# <b>xlim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set x-axis limit.
# <br>
# <br>
# <b>ylim: [float, float] or None</b>, default: lim
# <br>
# <i>axes-axislabel arguments with the return is [bottom, top]</i>
# <br>
# Set y-axis limit.
# <br>
# <br>
# <b>log: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis and y-axis scale.
# <br>
# <br>
# <b>xlog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set x-axis scale.
# <br>
# <br>
# <b>ylog: str or None</b>, default: log
# <br>
# <i>axes-axislabel arguments with the return is 'linear', 'log', 'symlog', or 'logit'</i>
# <br>
# Set y-axis scale.
# <br>
# <br>
# <b>dt: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# Both x-axis and y-axis date time format.
# <br>
# <br>
# <b>xdt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# x-axis date time format.
# <br>
# <br>
# <b>ydt: str or None</b>, default: dt
# <br>
# <i>axes-axislabel arguments with the return refers to python string format time</i>
# <br>
# y-axis date time format.
# <br>
# <br>
# <b>tick_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to both x-axis and y-axis ticks and text annotations.
# <br>
# <br>
# <b>xtick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to x-axis tick and text annotation.
# <br>
# <br>
# <b>ytick_add: str or None</b>, default: tick_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', '{}\_{}', '{}(\_)', '(\_){}', or '{}(\_){}' where {} is unit to add and () means negative representation if exists</i>
# <br>
# Add unit to y-axis tick and text annotation.
# <br>
# <br>
# <b>rot: float or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis tick rotation.
# <br>
# <br>
# <b>xrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis tick rotation.
# <br>
# <br>
# <b>yrot: float or None</b>, default: rot
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis tick rotation.
# <br>
# <br>
# <b>statdesc: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# Both x-axis and y-axis statistical description.
# <br>
# <br>
# <b>xstatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# x-axis statistical description.
# <br>
# <br>
# <b>ystatdesc: str or None</b>, default: statdesc
# <br>
# <i>axes-axislabel arguments with the base return is 'general', 'boxplot', 'count', 'nonzero', 'unique', 'std', 'range', 'min', 'pct1', 'whislo', 'pct5', 'q1', 'cilo', 'median', 'mean', 'cihi', 'q3', 'pct95', 'whishi', 'pct99', or 'max' can be passed by 'stat' or 'stat1+stat2+...'</i>
# <br>
# y-axis statistical description.
# <br>
# <br>
# <b>text: bool or None</b>, default: None
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# Both x-axis and y-axis text annotation.
# <br>
# <br>
# <b>xtext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# x-axis text annotation.
# <br>
# <br>
# <b>ytext: bool or None</b>, default: text
# <br>
# <i>axes-axislabel arguments</i>
# <br>
# y-axis text annotation.
# <br>
# <br>
# <b>label_add: str or None</b>, default: None
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to both x-axis and y-axis labels.
# <br>
# <br>
# <b>xlabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to x-axis label.
# <br>
# <br>
# <b>ylabel_add: str or None</b>, default: label_add
# <br>
# <i>axes-axislabel arguments with the return is '{}\_', '\_{}', or '{}\_{}' where {} is unit to add</i>
# <br>
# Add unit to y-axis label.
# <br>
# <br>
# <b>xlabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set x-axis label. Will override xlabel_add.
# <br>
# <br>
# <b>ylabel: str or None</b>, default: None
# <br>
# <i>axes arguments</i>
# <br>
# Set y-axis label. Will override ylabel_add.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>optimizer: str</b>, default: 'perf'
# <br>
# <i>ordinary argument with the return is 'numpy', 'saver', 'pandas', or 'perf'</i>
# <br>
# Data processing optimization mode. 'numpy' or 'saver' uses less memory, but slow. 'pandas' or 'perf' is fast, but uses more memory.
# <br>
# <br>
# <b>lowess: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Fit a lowess smoother to the residual scatterplot.
# <br>
# <br>
# <b>x_partial: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key or list-keys in df</i>
# <br>
# Confounding variables to regress out of the x variable before plotting.
# <br>
# <br>
# <b>y_partial: str or None</b>, default: None
# <br>
# <i>axes-plot arguments with the return is key or list-keys in df</i>
# <br>
# Confounding variables to regress out of the y variable before plotting.
# <br>
# <br>
# <b>order: int or None</b>, default: 1
# <br>
# <i>axes-plot arguments</i>
# <br>
# Order of the polynomial to fit when calculating the residuals.
# <br>
# <br>
# <b>robust: bool or None</b>, default: False
# <br>
# <i>axes-plot arguments</i>
# <br>
# Fit a robust linear regression when calculating the residuals.
# <br>
# <br>
# <b>dropna: bool or None</b>, default: True
# <br>
# <i>axes-plot arguments</i>
# <br>
# If True, ignore observations with missing data when fitting and plotting.
# <br>
# <br>
# <b>label: str or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Label that will be used in any plot legends.
# <br>
# <br>
# <b>color: matplotlib.colors or None</b>, default: None
# <br>
# <i>axes-plot arguments</i>
# <br>
# Color to use for all elements of the plot.
# <br>
# <br>
# <b>scatter_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional keyword arguments to pass to plt.scatter.
# <br>
# <br>
# <b>line_kws: dict or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Additional keyword arguments to pass to plt.plot.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot='residplot', 
            df=tips.head(10), 
            x='tip', 
            y='total_bill', 
            sep='.c', 
            text=True,
            tick_add='Rp(_)',
            title='total_bill vs tip rate')

# %% [markdown]
# ## Dashboard-Like
# Example

# %% [markdown]
# ### 1 Dimensional

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')
import pandas as pd

flights = gs.load_dataset('flights')
flights['month'] = flights['month'].cat.codes + 1
flights['date'] = pd.to_datetime(flights[['year', 'month']].assign(DAY=1))
flights = flights.drop(labels=['year', 'month'], axis=1)
ax = plot2d(plot={'[1]':'lineplot+scatterplot', '[2]':'histplot'},
            Nx=2,
            Ny=1,
            df=flights, 
            x=['date', 'passengers'], 
            y=['passengers', None],
            figsize=[16,6],
            fontsize=12,
            legend_fontsize=9,
            sep={'passengers':'.', 'year':None},
            xdt={'[1]':'%y %b'},
            ytext={'[2]':'h'}, 
            statdesc={'[1]':{'passengers':'count+unique'}, '[2]':{'passengers':'general'}},
            title={'[1]':'Line passengers vs date', '[2]':'Hist Count vs passengers'}
            )

# %% [markdown]
# ### 2 Dimensional

# %%
from grplot import plot2d
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')


tips = gs.load_dataset('tips')
ax = plot2d(plot={'[1,1]':'histplot', '[1,2]':'ecdfplot', '[2,1]':'treemapsplot', '[2,2]':'pieplot', '[3,1]':'paretoplot', '[3,2]':'boxplot+stripplot'}, 
            Nx=2,
            Ny=3,
            df=tips, 
            filter=(tips['total_bill'] > 10),
            x=['total_bill', 'total_bill', 'day', 'day', 'day', 'total_bill'], 
            y=[None, None, None, None, 'total_bill', 'day'], 
            hpad=6,
            wpad=8,
            figsize=[18,16], 
            fontsize=12, 
            legend_fontsize=11,
            sep={'total_bill':'.c', '.':['Count', 'Proportion', '[2,1]', '[2,2]', 'Cumulative Percentage']}, 
            statdesc={'[1,1]':{'total_bill':'general'}, '[3,2]':{'total_bill':'boxplot'}},
            text={'Count':'h', True:['[2,1]', '[2,2]'], '[3,1]':{'total_bill':'h+i'}},
            tick_add={'total_bill':'Rp(_)'},
            title={'[1,1]':'Histogram Count vs total_bill', '[1,2]':'ECDF Proportion vs total_bill', '[2,1]':'Treemaps of day',  '[2,2]':'Pie of day', '[3,1]':'Pareto total_bill vs day', '[3,2]':'Box day vs total_bill'},
            alpha={'[1,1]':0.75, '[3,1]':0.75},
            alpha2={'[3,1]':0.75},
            kde=True)

# %% [markdown]
# # Analytic

# %% [markdown]
# ## Cohort

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>df: pandas dataframe, dictionary-list, or dictionary-numpy.array</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Input data structure.
# <br>
# <br>
# <b>customer_id: str</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Customer ID column input.
# <br>
# <br>
# <b>signup_date: str</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Signup date column input.
# <br>
# <br>
# <b>last_active_date: str</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Last active date column input.
# <br>
# <br>
# <b>figsize: [float, float]</b>, default: [8, 6]
# <br>
# <i>ordinary argument</i>
# <br>
# Width, height in inches.
# <br>
# <br>
# <b>title: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Plot title.
# <br>
# <br>
# <b>fontsize: float</b>, default: 10
# <br>
# <i>ordinary argument</i>
# <br>
# Font size.
# <br>
# <br>
# <b>tick_fontsize: float or None</b>, default: fontsize
# <br>
# <i>ordinary argument</i>
# <br>
# Font size for tick.
# <br>
# <br>
# <b>legend_fontsize: float or None</b>, default: fontsize
# <br>
# <i>ordinary argument</i>
# <br>
# Font size for legend.
# <br>
# <br>
# <b>label_fontsize: float or None</b>, default: fontsize
# <br>
# <i>ordinary argument</i>
# <br>
# Font size for label.
# <br>
# <br>
# <b>title_fontsize: float or None</b>, default: fontsize
# <br>
# <i>ordinary argument</i>
# <br>
# Font size for title.
# <br>
# <br>
# <b>sep: str or None</b>, default: ','
# <br>
# <i>ordinary argument with the return is '.', ',', '.c', ',c', '.L', ',L', '.cL', or ',cL'</i>
# <br>
# Numerical thousand separator. c stands for currency. L stands for large number abbreviation using K, M, B, T, and Q.
# <br>
# <br>
# <b>saveas: str or None</b>, default: None
# <br>
# <i>ordinary argument</i>
# <br>
# Save figure as png, pdf, svg, or eps file. The format is inferred from the file name.
# <br>
# <br>
# <b>display_summary: boolean or None</b>, default: False
# <br>
# <i>ordinary argument</i>
# <br>
# To show cohort table summary.
# <br>
# <br>
# <br>
# <b>Returns: matplotlib.axes.Axes</b>
# <br>The matplotlib axes containing the plot.

# %%
from grplot.analytic import cohort
import grplot_seaborn as gs
gs.set_theme(context='notebook', style='darkgrid', palette='deep')
import pandas as pd


df = pd.read_csv('https://github.com/ghiffaryr/grplot_data/raw/main/retail_raw_reduced.csv', parse_dates=['order_date'])
df['last_active_date'] = df.groupby('customer_id')['order_date'].transform('max')
ax = cohort(df=df,
            customer_id='customer_id',
            signup_date='order_date',
            last_active_date='last_active_date',
            figsize=[16,12],
            fontsize=16,
            sep='.',
            display_summary=True)
# Out:
#                              Metric  Total Account
# Cohort Group Cohort Period
# 2019-07      0              2019-07            349
#              1              2019-08            226
#              2              2019-09            221
#              3              2019-10            207
#              4              2019-11            168
#              5              2019-12            129
# 2019-08      0              2019-08            298
#              1              2019-09            154
#              2              2019-10            140
#              3              2019-11            111
#              4              2019-12             77
# 2019-09      0              2019-09            180
#              1              2019-10             87
#              2              2019-11             77
#              3              2019-12             47
# 2019-10      0              2019-10            336
#              1              2019-11            104
# ...

# %% [markdown]
# ## Rank Order, Gain, KS, and Lift

# %% [markdown]
# <b>Parameters:</b>
# <br>
# <br>
# <br>
# <b>predict_proba: numpy.ndarray or pandas.core.frame.DataFrame</b>
# <br>
# <i>ordinary argument</i>
# <br>
# All class prediction probability data.
# <br>
# <br>
# <b>true_label: list, numpy.ndarray, or pandas.core.series.Series</b>
# <br>
# <i>ordinary argument</i>
# <br>
# Actual label data.
# <br>
# <br>
# <b>class_non_event: int</b>, default: 1
# <br>
# <i>ordinary argument</i>
# <br>
# Class non event to summarize. One-vs-Rest is possible.
# <br>
# <br>
# <b>display_table: boolean or None</b>, default: True
# <br>
# <i>ordinary argument</i>
# <br>
# To show table.
# <br>
# <br>
# <br>
# <b>Returns: pandas.core.frame.DataFrame</b>
# <br>Rank Order, Gain, KS, and Lift table.

# %%
from grplot.analytic import rank_order
import numpy as np
np.random.seed(0)

predict_proba = np.array([np.random.uniform(low=0.1, high=1.0, size=10), # class 0
                            np.random.uniform(low=0.1, high=1.0, size=10)]) # class 1
predict_proba = np.swapaxes(predict_proba, 0, 1)
true_label = np.random.randint(low=0, high=2, size=10)
rank_order_table = rank_order(predict_proba=predict_proba,
                              true_label=true_label,
                              class_non_event=1)
# Out:
#         Minimum Prediction Probability  Maximum Prediction Probability  \
# Decile
# 9                             0.933037                        0.933037
# 8                             0.883011                        0.883011
# 7                             0.849358                        0.849358
# 6                             0.812553                        0.812553
# 5                             0.800341                        0.800341
# 4                             0.611240                        0.611240
# 3                             0.576005                        0.576005
# 2                             0.178416                        0.178416
# 1                             0.163932                        0.163932
# 0                             0.118197                        0.118197
#
#         Mean Prediction Probability  Count Customer  Count Non-event  \
# Decile
# 9                          0.933037               1                1
# ...
